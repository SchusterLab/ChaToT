# %%
import sys, datetime
from qick.asm_v2 import QickSweep1D

sys.path.append("../Libraries") # replace this with your location of the Libraries folder
from excited_measurement import *
# Out:
# No module named 'visa'
# Warning VISA library import failed
# Warning serial library import failed.
# Could not load Autonics TM4 Driver

# %%
date = str(datetime.datetime.now().strftime('%Y_%m_%d'))
time = str(datetime.datetime.now().strftime('%H;%M;%S'))

datapath = f'G:\\My Drive\\chatot\\data\\excited_measurement\\{date}\\{time}\\' # replace this with your data location

config_file = f"..\\..\\..\\..\\cfg\\llosta.json" # replace this with your config

meas = excited_measurement(path=datapath, config_file=config_file)

meas.cfg.expt = {
    "n_avg": 10000,
    "ro_len": 13,
    "res_pulse_len": 12,
    "res_freq": 5984.9,
    "res_phase": 0,
    "res_gain": 0.03,
    "trig_offset": 0
}

data = meas.acquire()
meas.display(save=True)
meas.savedata()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Creating directory G:\My Drive\chatot\data\excited_measurement\2025_03_25\02;53;35\
# Data saved to G:\My Drive\chatot\data\excited_measurement\2025_03_25\02;53;35\data.h5
# Config saved to G:\My Drive\chatot\data\excited_measurement\2025_03_25\02;53;35\cfg.json
