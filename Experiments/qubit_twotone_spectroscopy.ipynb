# %%
import sys, datetime
from qick.asm_v2 import QickSweep1D

sys.path.append("../Libraries") # replace this with your location of the Libraries folder
from qubit_twotone_spectroscopy import *
# Out:
# No module named 'visa'
# Warning VISA library import failed
# Warning serial library import failed.
# Could not load Autonics TM4 Driver

# %%
date = str(datetime.datetime.now().strftime('%Y_%m_%d'))
time = str(datetime.datetime.now().strftime('%H;%M;%S'))

datapath = f'G:\\My Drive\\chatot\\data\\qubit_twotone_spectroscopy\\{date}\\{time}\\' # replace this with your data location

config_file = f"..\\..\\..\\..\\cfg\\llosta.json" # replace this with your config

meas = qubit_twotone_spectroscopy(path=datapath, config_file=config_file)

center = 4277
span = 10

meas.cfg.expt = {
    "n_avg": 500,
    "res_freq": 5990.45,
    "res_gain": 0.03,
    "res_pulse_len": 5, 
    "res_phase": 0,
    "qubit_pulse_len": 0.37, 
    "qubit_gain": 0.2,
    "qubit_freq": QickSweep1D('freq_loop', center - span, center + span),
    "qubit_phase": 0,
    "trig_offset": 0.5,
    "relaxation_time": 20,
    "steps": 1000,
    "center": center,
    "span": span
}

meas.acquire()
meas.display(save=True)
meas.savedata()
# Out:
#   0%|          | 0/500000 [00:00<?, ?it/s]
# Creating directory G:\My Drive\chatot\data\qubit_twotone_spectroscopy\2025_05_26\01;19;51\
# Data saved to G:\My Drive\chatot\data\qubit_twotone_spectroscopy\2025_05_26\01;19;51\data.h5
# Config saved to G:\My Drive\chatot\data\qubit_twotone_spectroscopy\2025_05_26\01;19;51\cfg.json
