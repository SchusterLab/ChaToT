# %% [markdown]
# ## Imports

# %%
import sys
import datetime

sys.path.append("../Libraries") # replace this with your location of the Libraries folder
from time_of_flight import *
# Out:
# No module named 'visa'
# Warning VISA library import failed
# Warning serial library import failed.
# Could not load Autonics TM4 Driver

# %% [markdown]
# ## Run Experiment

# %%
date = str(datetime.datetime.now().strftime('%Y_%m_%d'))
time = str(datetime.datetime.now().strftime('%H;%M;%S'))

datapath = f'G:\\My Drive\\chatot\\data\\time_of_flight\\{date}\\{time}\\' # replace this with your data location

config_file = f"..\\..\\..\\..\\cfg\\time_of_flight.json" # replace this with your config

meas = time_of_flight(path=datapath, config_file=config_file)

meas.acquire()
meas.display()
# Out:
# Creating directory G:\My Drive\chatot\data\time_of_flight\2024_11_03\13;38;43\
# G:\My Drive\chatot\data\time_of_flight\2024_11_03\13;38;43\00000_time_of_flight.h5
# time_of_flight
# G:\My Drive\chatot\data\time_of_flight\2024_11_03\13;38;43\
# Pyro.NameServer PYRO:Pyro.NameServer@0.0.0.0:8884
# chatot PYRO:obj_9ee4e13cf1664ba186072565cf8d260e@192.168.137.104:38479
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
from slab import SlabFile
SlabFile(f"G:\\My Drive\\chatot\\data\\time_of_flight\\2024_11_03\\13;38;43\\00000_time_of_flight.h5")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\csnipp\AppData\Local\Temp\10\ipykernel_500\98209432.py", line 2, in <module>
#     SlabFile(f"G:\\My Drive\\chatot\\data\\time_of_flight\\2024_11_03\\13;38;43\\00000_time_of_flight.h5")
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\slab\datamanagement.py", line 247, in __init__
#     h5py.File.__init__(self, *args, **kwargs)
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\h5py\_hl\files.py", line 562, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\h5py\_hl\files.py", line 235, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "h5py\\_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py\\_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py\\h5f.pyx", line 102, in h5py.h5f.open
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'G:\My Drive\chatot\data\time_of_flight\2024_11_03\13;38;43\00000_time_of_flight.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
meas.savedataXD()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\csnipp\AppData\Local\Temp\10\ipykernel_500\3324164206.py", line 1, in <module>
#     meas.savedataXD()
#   File "C:\Users\csnipp\Documents\charles_qick\Experiments\../Libraries\time_of_flight.py", line 110, in savedataXD
#     with self.datafile() as f:
#          ^^^^^^^^^^^^^^^
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\slab\experiment.py", line 73, in datafile
#     f = SlabFile(data_file)
#         ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\slab\datamanagement.py", line 247, in __init__
#     h5py.File.__init__(self, *args, **kwargs)
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\h5py\_hl\files.py", line 562, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\csnipp\Documents\charles_qick\Lib\site-packages\h5py\_hl\files.py", line 235, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "h5py\\_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py\\_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py\\h5f.pyx", line 102, in h5py.h5f.open
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'G:\My Drive\chatot\data\time_of_flight\2024_11_03\13;38;43\00000_time_of_flight.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
