# %%
import sys, datetime
from qick.asm_v2 import QickSweep1D

sys.path.append("../Libraries") # replace this with your location of the Libraries folder
from rabi_length import *

# %%
date = str(datetime.datetime.now().strftime('%Y_%m_%d'))
time = str(datetime.datetime.now().strftime('%H;%M;%S'))

datapath = f'G:\\My Drive\\chatot\\data\\rabi_length\\{date}\\{time}\\' # replace this with your data location

config_file = f"..\\..\\..\\..\\cfg\\llosta.json" # replace this with your config

meas = rabi_length(path=datapath, config_file=config_file)

min_length = 0.01
max_length = 5

meas.cfg.expt = {
    "n_avg": 10000,
    "res_freq": 5986.8,
    "res_gain": 0.1,
    "res_pulse_len": 5,
    "res_phase": 0,
    "qubit_pulse_len": QickSweep1D('length_loop', min_length, max_length),
    "qubit_gain": 0.05,
    "qubit_freq": 4304.5,
    "qubit_phase": 0,
    "trig_offset": 0.5,
    "relaxation_time": 1.5*max_length, # we set it to 1.5*max_length to avoid getting weird unexplained bifurcation
    "steps": 300,
    "min_length": min_length,
    "max_length": max_length,
}

meas.acquire()
meas.display(save=True)
meas.savedata()
# Out:
#   0%|          | 0/3000000 [00:00<?, ?it/s]
# Creating directory G:\My Drive\chatot\data\rabi_length\2025_01_01\16;57;37\
# Data saved to G:\My Drive\chatot\data\rabi_length\2025_01_01\16;57;37\data.h5
# Config saved to G:\My Drive\chatot\data\rabi_length\2025_01_01\16;57;37\cfg.json
