# %%
import sys, datetime
from qick.asm_v2 import QickSweep1D

sys.path.append("../Libraries") # replace this with your location of the Libraries folder
from resonator_power_spectroscopy import *
# Out:
# No module named 'visa'
# Warning VISA library import failed
# Warning serial library import failed.
# Could not load Autonics TM4 Driver

# %%
date = str(datetime.datetime.now().strftime('%Y_%m_%d'))
time = str(datetime.datetime.now().strftime('%H;%M;%S'))

datapath = f'G:\\My Drive\\chatot\\data\\resonator_power_spectroscopy\\{date}\\{time}\\' # replace this with your data location

config_file = f"..\\..\\..\\..\\cfg\\llosta.json" # replace this with your config

meas = resonator_power_spectroscopy(path=datapath, config_file=config_file)

#frequency
center = 5983.5
span = 3.5
#gain
min_gain = 0.25
max_gain = 0.35

meas.cfg.expt = {
    "n_avg": 500,
    "ro_len": 100,
    "pulse_len": 100,
    "phase": 0,
    "gain": QickSweep1D('gain_loop', min_gain, max_gain),
    "trig_offset": 0.5,
    "freq": QickSweep1D('freq_loop', center - span, center + span),
    "freq_steps": 50,
    "center": center,
    "span": span,
    "min_gain": min_gain,
    "max_gain": max_gain,
    "gain_steps": 11
}

meas.acquire()
meas.display(save=True)
meas.savedata()
# Out:
#   0%|          | 0/275000 [00:00<?, ?it/s]
# Creating directory G:\My Drive\chatot\data\resonator_power_spectroscopy\2024_12_19\01;02;49\
# Data saved to G:\My Drive\chatot\data\resonator_power_spectroscopy\2024_12_19\01;02;49\data.h5
# Config saved to G:\My Drive\chatot\data\resonator_power_spectroscopy\2024_12_19\01;02;49\cfg.json
