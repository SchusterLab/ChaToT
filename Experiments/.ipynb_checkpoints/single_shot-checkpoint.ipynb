# %%
import sys, datetime
from qick.asm_v2 import QickSweep1D

sys.path.append("../Libraries") # replace this with your location of the Libraries folder
from single_shot import *
# Out:
# No module named 'visa'
# Warning VISA library import failed
# Warning serial library import failed.
# Could not load Autonics TM4 Driver

# %%
date = str(datetime.datetime.now().strftime('%Y_%m_%d'))
time = str(datetime.datetime.now().strftime('%H;%M;%S'))

datapath = f'G:\\My Drive\\chatot\\data\\single_shot\\{date}\\{time}\\' # replace this with your data location

config_file = f"..\\..\\..\\..\\cfg\\llosta.json" # replace this with your config

meas = single_shot(path=datapath, config_file=config_file)

meas.cfg.expt = {
    "n_count": 10000,
    "res_freq": 5984.9,
    "res_gain": 0.03,
    "res_pulse_len": 5, 
    "res_phase": 0,
    "trig_offset": 0.5,
    "relaxation_time": 400
}

meas.cfg.pulses.pi_gaus = {
	"length": 0.37,
	"freq": 4303.7,
	"phase": 0,
	"gain": 0.2
	}

meas.acquire()
meas.display(save=True)
meas.savedata()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Creating directory G:\My Drive\chatot\data\single_shot\2025_03_31\22;10;45\
# Data saved to G:\My Drive\chatot\data\single_shot\2025_03_31\22;10;45\data.h5
# Config saved to G:\My Drive\chatot\data\single_shot\2025_03_31\22;10;45\cfg.json
